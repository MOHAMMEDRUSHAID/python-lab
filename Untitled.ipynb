# %%
a=int(input("enter a"))
b=int(input("enter b"))
d=a+b
print("add",d)
# Out:
# enter a3
# enter b5
# add 8

# %%
a=int(input("enter a"))
b=int(input("enter b"))
d=a-b
print("diff",d)
# Out:
# enter a5
# enter b3
# diff 2

# %%
a=int(input("enter a"))
b=int(input("enter b"))
d=a/b
c=a%b
print("qua",d)
print("reminder",c)
# Out:
# enter a5
# enter b3
# qua 1.6666666666666667
# reminder 2

# %%
r=int(input("enter radius of circle"))
b=3.14*r*r
print("area",b)
# Out:
# enter radius of circle5
# area 78.5

# %%
a=int(input("enter a"))
b=int(input("enter b"))
c=int(input("enter c"))
d=(a+b+c)/3
print("average",d)
# Out:
# enter a10
# enter b20
# enter c30
# average 20.0

# %%
a=int(input("enter in celcius"))
d=(a*9/5)+32
print("fahrenheit",d)
# Out:
# enter in celcius25
# fahrenheit 77.0

# %%
a=int(input("enter number"))
d=(a-32)*5/9
print("celcius",d)
# Out:
# enter number77
# celcius 25.0

# %%
# Out:
# === TEMPERATURE CONVERTER ===
# 1. Celsius to Fahrenheit
# 2. Celsius to Kelvin
# 3. Fahrenheit to Celsius
# 4. Fahrenheit to Kelvin
# 5. Kelvin to Celsius
# 6. Kelvin to Fahrenheit
# 7. Exit
#
# Enter your choice (1-7): 5
# Enter the temperature value to convert: 34
# 34.0K = -239.15°C
#
# === TEMPERATURE CONVERTER ===
# 1. Celsius to Fahrenheit
# 2. Celsius to Kelvin
# 3. Fahrenheit to Celsius
# 4. Fahrenheit to Kelvin
# 5. Kelvin to Celsius
# 6. Kelvin to Fahrenheit
# 7. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4208/849743478.py in <module>
#      57
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# ~\AppData\Local\Temp/ipykernel_4208/849743478.py in main()
#      28         print("7. Exit")
#      29
# ---> 30         choice = input("\nEnter your choice (1-7): ")
#      31
#      32         if choice == '7':
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
a=int(input("enter a"))
if(a>100):
    print("number is greater than 1oo")
else:
    print("number is less than 100")
# Out:
# enter a89
# number is less than 100

# %%
a=int(input("enter a number"))
if(a>=0):
    print("number is positive")
else:
    print("number is negative")
# Out:
# enter a number-1
# number is negative

# %%
a=int(input("enter a number"))
if(a%2==0):
    print("number is even")
else:
    print("number is odd")
# Out:
# enter a number3
# number is odd

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
if (a==b):
   print("both numbers are equal")
else:
   print("number are not equal")
# Out:
# enter a number23
# enter a number23
# both numbers are equal

# %%
a=int(input("entr a number"))
b=int(input("enter a number"))
if (a>b):
    print("a is the biggest")
else:
    print("b is biggest")
# Out:
# entr a number89
# enter a number78
# a is the biggest

# %%
a=int(input("enter persons age"))
if(a>18):
    print("person is eligible")
else:
    print("person is not eligble")
# Out:
# enter persons age17
# person is not eligble

# %%
a=int(input("enter a number"))
if (a%5==0):
    print("number is divisible by 5")
else:
    print("number is not divisible 5")
# Out:
# enter a number3
# number ids not divisible 5
