# %%
a=int(input("enter a"))
b=int(input("enter b"))
d=a+b
print("add",d)
# Out:
# enter a3
# enter b5
# add 8

# %%
a=int(input("enter a"))
b=int(input("enter b"))
d=a-b
print("diff",d)
# Out:
# enter a5
# enter b3
# diff 2

# %%
a=int(input("enter a"))
b=int(input("enter b"))
d=a/b
c=a%b
print("qua",d)
print("reminder",c)
# Out:
# enter a5
# enter b3
# qua 1.6666666666666667
# reminder 2

# %%
r=int(input("enter radius of circle"))
b=3.14*r*r
print("area",b)
# Out:
# enter radius of circle5
# area 78.5

# %%
a=int(input("enter a"))
b=int(input("enter b"))
c=int(input("enter c"))
d=(a+b+c)/3
print("average",d)
# Out:
# enter a10
# enter b20
# enter c30
# average 20.0

# %%
a=int(input("enter in celcius"))
d=(a*9/5)+32
print("fahrenheit",d)
# Out:
# enter in celcius25
# fahrenheit 77.0

# %%
a=int(input("enter number"))
d=(a-32)*5/9
print("celcius",d)
# Out:
# enter number77
# celcius 25.0
