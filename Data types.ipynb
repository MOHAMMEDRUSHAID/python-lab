# %%
mark=[37,45,67,89,34,]
print(mark[0])
# Out:
# 37

# %%
a=[10,20,30,40,50]
a.append(60)
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a=(10,20,30,40,50,)
print(a[2])
# Out:
# 30

# %%
set={10,20,30,40,50,40}
print(set)
# Out:
# {50, 20, 40, 10, 30}

# %%
student={"name":"rushie","age":20}
print(student['name'])
# Out:
# rushie

# %%
name="rushaid"
print(name[0])
print(name[6])
# Out:
# r
# d
