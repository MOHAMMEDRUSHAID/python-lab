# %%
a=int(input("enter a number"))
if a%7==0:
    print("number is divisible by 7")
else:
    print("number is not divisible by 7")
# Out:
# enter a number6
# number is not divisible by 7

# %%
a=(input("enter a character"))
vowels = "aeiouAEIOUS"
if a in vowels:
    print("char is vowels")
else:
    print("char is not vowels")
# Out:
# enter a characters
# char is mot vowels

# %%
age=int(input("enter persons age :"))
if age>=18:
    print("person is eligible for licence")
else:
    print("person is not eligible for licence")
# Out:
# enter persons age :45
# person is eligible for licence

# %%
a=(input("enter a string :"))
b=(input("enter a string :"))
if a==b:
    print("both character are equal")
else:
    print("both character are not eqyual")
# Out:
# enter a character :apple
# enter a character :apple
# both character are equal

# %%
a=int(input("purchasing amount :"))
if a>=5000:
    print("Eligible for Discount")
else:
    print("Not Eligible for discount")
# Out:
# purchasing amount :6000
# Eligible for Discount

# %%
num=int(input("enter a number :"))
if num>10 and num<100:
    print("number is between 10 and 100")
else:
    print("number is not lies between 10 and 100")
# Out:
# enter a number :1
# number is not lies between 10 and 100

# %%
p=int(input("enter percentage"))
if p>=75:
    print("eligible for exam")
else:
    print("not eligible for exam")
# Out:
# enter percentage67
# not eligible for exam

# %%
a=input("enter a ALPHABET :")
if a.isupper():
    print("capital LETTER")
else:
    print("small LETTER")
# Out:
# enter a letterE
# capital

# %%
a=int(input("enter a number"))
if a>100 and a<999:
    print("number is 3 digit number")
else:
    print("number is not 3 digit number")
# Out:
# enter a number6789
# number is not 3 digit number

# %%
a=float(input("enter usage of data in GB:"))
if a<=2:
    print("LOW USAGE")
elif a>2 and a<=5:
    print("MODERATE USAGE")
else:
    print("high usage")
# Out:
# enter usage of data in GB:2.7
# MODERATE USAGE
